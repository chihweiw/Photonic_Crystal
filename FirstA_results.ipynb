# %% [markdown]
# ![Tasks_2_1.png](attachment:756e68a6-f8d0-4516-b909-78f9313ae8e1.png)

# %% [markdown]
# Tasks 2.1: The blue line is the theoretical prediction and red dots are the results of the simulation.

# %% [markdown]
# ![Tasks_2_2.png](attachment:d9715e52-d4e2-46e6-9ff2-1160947684b9.png)

# %% [markdown]
# Tasks 2.2

# %% [markdown]
# ![Tasks_2_3.png](attachment:75a2b400-92ea-4bee-880a-889457f44952.png)

# %% [markdown]
# Tasks 2.3

# %% [markdown]
# ![Tasks_2_4(5).png](attachment:5fc18550-30ea-4886-8f69-290541fb3ee6.png)

# %% [markdown]
# Tasks 2.4(5)

# %% [markdown]
# ![Tasks_2_4(10).png](attachment:d226eab0-17e4-47c6-957b-7c41d1a42a81.png)

# %% [markdown]
# Tasks 2.4(10)

# %% [markdown]
# ![Tasks_2_5(5).png](attachment:3173b870-d861-486b-9e8f-5b6830932974.png)

# %% [markdown]
# Tasks 2.5(5)

# %% [markdown]
# ![Tasks_2_5(10).png](attachment:b6492080-f183-4672-afd5-9d5faf6cdac0.png)

# %% [markdown]
# Tasks 2.5(10)
